# %% [markdown]
# # 1. Importing and unpacking files

# %%
import kaggle

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

# %%
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('danielgrijalvas/movies', path=".")

# %%
import zipfile

# %%
with zipfile.ZipFile('movies.zip', 'r') as zipref:
    zipref.extractall()

# %% [markdown]
# # 2. Importing essential libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
# matplotlib.rcParams['figure.figsize'] = (12,8) # to adjust the configuration of the plots we will create


# Read in the data

df = pd.read_csv(r'C:\Users\Igorm\Desktop\Project Py\Project_two_Cleaning_&_Python\movies.csv')

# %%
# Check the data how they look

# df.sample()
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Checking if there is any missing data:

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %% [markdown]
# # 3. Cleaning the data

# %%
# Purpose of this work: checking the correlation of the data


df = df.dropna()

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Data types for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %% [markdown]
# # 4. Changing necessary data types into other format

# %%
# Changing float values into integers (in purposen of deleting additional .0)


df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# To check if there are any outliers:

df.boxplot(column=['gross'])
# Out:
# <AxesSubplot:>

# %%
# Drop wrong Column by Index (optional - in case of mistake)

# df.drop('YearCorrect', axis = 1, inplace=True)

# df.drop(df.columns[15], axis=1, inplace=True)
# df

# %% [markdown]
# # 5. Adding additional column

# %%
# Create correct Year column

# df['YearCorrect'] = df['released'].astype(str).str[0:4]

df['yearcorrect'] = df['released'].astype(str).str.split(', ').str[-1].astype(str).str[:4]

# df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)

# %%
# df.columns['YearCorrect']
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df.dtypes
# Out:
# name            object
# rating          object
# genre           object
# year             int64
# released        object
# score          float64
# votes          float64
# director        object
# writer          object
# star            object
# country         object
# budget           int64
# gross            int64
# company         object
# runtime        float64
# yearcorrect     object
# dtype: object

# %%
df = df.sort_values(by='gross', ascending=False)

# %%
#  to show more rows than default

pd.set_option('display.max_rows', 500)

# %% [markdown]
# # 6. Droping any duplicates

# %%
#  Drop any duplicates - as an example of companies

df['company'].drop_duplicates().sort_values(ascending=False)
# df['company'].sort_values(ascending=False)

#  that will drop any duplicates across df:
# df.drop_duplicates()
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
#                        ...
# 385                        1818 Productions
# 2929                          1492 Pictures
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %% [markdown]
# # 7. Checking most correlatet things to the reveniue:

# %% [markdown]
# 1. Budget high correlation
# 2. Company high correlation

# %%
# Optional - to test
# df.iloc[:10,1:15]
# df.query("gross< budget").sort_values(by='budget', ascending=False)
# Out:
#                                   name     rating      genre  year  \
# 5146                     Evan Almighty         PG     Comedy  2007
# 7081  King Arthur: Legend of the Sword      PG-13     Action  2017
# 6312                          47 Ronin      PG-13     Action  2013
# 3485                  The 13th Warrior          R     Action  1999
# 7465                      The Irishman          R  Biography  2019
# ...                                ...        ...        ...   ...
# 142                         The Beyond          R     Horror  1981
# 7604                            Mine 9  Not Rated      Drama  2019
# 4187                            Dahmer          R  Biography  2002
# 3024                       Schizopolis  Not Rated     Comedy  1996
# 467               My Brother's Wedding  Not Rated      Drama  1983
#
#                                released  score     votes           director  \
# 5146      June 22, 2007 (United States)    5.4  142000.0        Tom Shadyac
# ...

# %% [markdown]
# # 8. Visualization part

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earning')
plt.xlabel('Gross Earning')
plt.ylabel('Budget for movie')
# changing size of the plot:
plt.rcParams["figure.figsize"] = (15, 10)
# df.plot(figsize=(15,10))

plt.show()

# %%
#  Regression plot - plot budget with seaborn

sns.regplot(x='gross', y='budget', data=df, scatter_kws={"color":"red"}, line_kws={"color":"orange"})
# Out:
# <AxesSubplot:xlabel='gross', ylabel='budget'>

# %%
# Let's start looking at Correleation Matrix
# different methods of correlaton: #pearson, #kendall #spearman

# %%
df.corr() #pearson
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
df.corr(method='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
# score    0.039389  1.000000  0.350185 -0.006406  0.124943  0.292254
# votes    0.296512  0.350185  1.000000  0.346274  0.553625  0.205344
# budget   0.220833 -0.006406  0.346274  1.000000  0.512057  0.231278
# gross    0.239539  0.124943  0.553625  0.512057  1.000000  0.176979
# runtime  0.064824  0.292254  0.205344  0.231278  0.176979  1.000000

# %%
# only works on numeric value
# df.corr()  #pearson (by default), #kendall #spearman  
df.corr(method='spearman')

# high correlation between budget and gross, gross and votes
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.057741  0.427623  0.312886  0.351045  0.095444
# score    0.057741  1.000000  0.495409 -0.009971  0.183192  0.412155
# votes    0.427623  0.495409  1.000000  0.493461  0.745793  0.300621
# budget   0.312886 -0.009971  0.493461  1.000000  0.692958  0.330794
# gross    0.351045  0.183192  0.745793  0.692958  1.000000  0.257400
# runtime  0.095444  0.412155  0.300621  0.330794  0.257400  1.000000

# %%
# Visualization of the coorelation that was count
correlation_matrix = df.corr(method='spearman')

# annot - annotations
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matric for Numeric Values', fontsize=20)
plt.xlabel('Movie Features', fontsize=15)
plt.ylabel('Movie Features', fontsize=15)

plt.show()

# %%
# Looking for Company

# df.head()
df.dtypes
# Out:
# name            object
# rating          object
# genre           object
# year             int64
# released        object
# score          float64
# votes          float64
# director        object
# writer          object
# star            object
# country         object
# budget           int64
# gross            int64
# company         object
# runtime        float64
# yearcorrect     object
# dtype: object

# %% [markdown]
# # 9. Numerizing dataframe columns (object ones) into numbers

# %%
df_numerized = df

for col in df_numerized.columns:
    if(df_numerized[col].dtype == 'object'):
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes  # gives the random numerization

df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5640  3794       6      6  2009       890    5.8     3500.0       585    2924
# 2434  2969       5      0  1993      1467    4.5     1900.0      1805    3102
# 3681  1595       3      6  2000      1721    6.8    43000.0       952    1683
# 272   2909       6      9  1982      1525    3.9     2300.0       261      55
# 3203  4966       5      4  1997      2152    5.7     5800.0       651     161
#
# ...

# %%
df
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title('Correlation Matrix for Numeric Values')

plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
# filtering down:
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year         0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released    -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score        0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
# to see correlaction quickly - stocking
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#              score          0.014450
#              votes          0.012615
#              director       0.015246
#              writer         0.012880
#              star          -0.006882
#              country       -0.025490
#              budget         0.023392
#              gross          0.005639
#              company        0.021697
#              runtime        0.010850
#              yearcorrect    0.023234
# rating       name          -0.029234
#              rating         1.000000
#              genre          0.147796
#              year           0.019499
#              released       0.018083
#              score          0.065983
#              votes          0.006031
#              director       0.014656
#              writer        -0.003149
# ...

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.368523
# budget       genre         -0.368523
# gross        genre         -0.244101
# genre        gross         -0.244101
# rating       budget        -0.203946
# budget       rating        -0.203946
# rating       gross         -0.181906
# gross        rating        -0.181906
# votes        genre         -0.135990
# genre        votes         -0.135990
# company      rating        -0.092357
# rating       company       -0.092357
# country      yearcorrect   -0.074422
# yearcorrect  country       -0.074422
# year         genre         -0.073167
# genre        year          -0.073167
#              company       -0.071334
# company      genre         -0.071334
# year         country       -0.066748
# country      year          -0.066748
# genre        yearcorrect   -0.064308
# yearcorrect  genre         -0.064308
# genre        runtime       -0.059237
# runtime      genre         -0.059237
# score        country       -0.043051
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# votes        gross          0.614751
# gross        votes          0.614751
# budget       gross          0.740247
# gross        budget         0.740247
# yearcorrect  year           0.990417
# year         yearcorrect    0.990417
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %% [markdown]
# # 10. Summary:

# %% [markdown]
# 1. Votes and budget have the highest correlation to the gross earnings
# 2. Year - yearcorrect is irrelevant
# 3. Company and the other factors have relatively low correlation
